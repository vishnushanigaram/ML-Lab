# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %%
#Import the Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the data sets- train and test 
df=pd.read_csv('train.csv')
print(df.head())
# print(df.columns)
list=['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# print(df.isnull().sum())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
sns.countplot(x="Survived",data=df,ax=ax[0][0],color='red')
sns.countplot(x='Pclass', data=df,ax=ax[0][1])
sns.countplot(data=df,x='Sex',ax=ax[1][0])
sns.countplot(data=df,x='Embarked',ax=ax[1][1])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
fig , ax=plt.subplots(2,2,figsize=(10,10))

sns.histplot(df['Age'],bins=10 ,ax=ax[0][0],kde=True)
sns.histplot(df['Parch'],bins=10,kde=True,ax=ax[0][1] ,color='green')
sns.histplot(df['Fare'],bins=10,kde=True,ax=ax[1][0],color='orange')
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
fig, ax=plt.subplots(2,2,figsize=(10,10))

sns.histplot(df[df['Survived']==1]['Age'],bins=10,ax=ax[0][0],kde=True)
plt.title('Survived')
plt.xlabel('Survived')
sns.histplot(df[df['Survived']==1]['Age'],bins=10,ax=ax[0][1],kde=True)
plt.title('Did not Survived')
plt.xlabel('Did not Survived')
plt.show()

# %%
#Print the dimension of train and test data
print(df.shape)
# Out:
# (891, 12)

# %%
#Print the number of missing values in each column of train and test data

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_style("whitegrid")

# Create subplots for better visualization
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Bar plot for Survived
sns.countplot(data=df, x='Survived', palette='coolwarm', ax=axes[0, 0])
axes[0, 0].set_title('Survival Count')

# Bar plot for Pclass
sns.countplot(data=df, x='Pclass', palette='muted', ax=axes[0, 1])
axes[0, 1].set_title('Passenger Class Distribution')

# Bar plot for Sex
sns.countplot(data=df, x='Sex', palette='pastel', ax=axes[1, 0])
axes[1, 0].set_title('Gender Distribution')

# Bar plot for Embarked
sns.countplot(data=df, x='Embarked', palette='viridis', ax=axes[1, 1])
axes[1, 1].set_title('Port of Embarkation')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Mr_Perfect\AppData\Local\Temp\ipykernel_4372\1348966682.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Survived', palette='coolwarm', ax=axes[0, 0])
# C:\Users\Mr_Perfect\AppData\Local\Temp\ipykernel_4372\1348966682.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Pclass', palette='muted', ax=axes[0, 1])
# C:\Users\Mr_Perfect\AppData\Local\Temp\ipykernel_4372\1348966682.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Sex', palette='pastel', ax=axes[1, 0])
# ...

# %%
#Histogram of Age, Parch, Fare
fig,axes=plt.subplots(1,3,figsize=(15,5))
sns.histplot(df['Age'], bins=10,ax=axes[0],kde=True)

sns.histplot(df['Parch'], bins=10,ax=axes[1],kde=True)

sns.histplot(df['Fare'], bins=10,ax=axes[2],kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
#Plot histogram of age for survived and did not survived class
fig,axes=plt.subplots(1,4,figsize=(15,5))
sns.histplot(df[df['Survived']==1]['Age'], bins=10,ax=axes[0],kde=True)
sns.histplot(df[df['Survived']==0]['Age'],bins=10,ax=axes[1])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#Count class and geder wise survival rate - plot with appropriate chart
# fig,axes=plt.subplots(1,2,figsize=(15,5))
# ans=sns.countplot(data=df,x='Pclass',hue='Survived',ax=axes[0])
# print("This is the ",ans)

#Age wise Distribution of Male and Female passengers
#fig,axes=plt.subplots(1,1,figsize=(15,5))
sns.histplot(data=df,x='Age',hue='Sex',kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#Histogram of Age of the given data set(sample)
sns.histplot(data=df,x='Age',bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace the msiing values in Embarked column by 'S'
df['Embarked'].fillna('S',inplace=True)
df.isnull().sum()
# Out:
# C:\Users\Mr_Perfect\AppData\Local\Temp\ipykernel_4372\2893911860.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('S',inplace=True)
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
#Impute the missing values in Fare column with median value.
df['Fare'].fillna(df['Fare'].median(),inplace=True)
df.isnull().sum()
# Out:
# C:\Users\Mr_Perfect\AppData\Local\Temp\ipykernel_4372\3135309389.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fare'].fillna(df['Fare'].median(),inplace=True)
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
#Impute the Age column. It has too many missing values but it may be important.    
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data

mean_age = df['Age'].mean()
std_age = df['Age'].std()

random_ages = np.random.normal(mean_age, std_age, df['Age'].isnull().sum())

# Fill missing Age values with the generated random values
df.loc[df['Age'].isnull(), 'Age'] = random_ages

print(df['Age'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch + SibSp + 1


df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# df.head(df['SibSp','Parch','FamilySize'])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# ...

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False

df['isAlone'] = df['FamilySize']==1
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  isAlone
# 0      0         A/5 21171   7.2500   NaN        S           2    False
# 1      0          PC 17599  71.2833   C85        C           2    False
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1     True
# ...

# %%
## Create a new attribute Has_cabin using the attribue Cabin. 
#if Cabin == NaN the Has_cabin = False else Has_cabin = True

df['Has_cabin']=~df['Cabin'].isnull()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  isAlone  \
# 0      0         A/5 21171   7.2500   NaN        S           2    False
# 1      0          PC 17599  71.2833   C85        C           2    False
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1     True
# ...

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId,Name,Ticket,and Cabin

# %% [markdown]
# ## Model Building

# %%
#Prepare X and y

y=df['Survived']
X=df.drop(['PassengerId','Survived','Name','Ticket','Cabin'],axis=1)
X.head()
# y.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked  FamilySize  isAlone  \
# 0       3    male  22.0      1      0   7.2500        S           2    False
# 1       1  female  38.0      1      0  71.2833        C           2    False
# 2       3  female  26.0      0      0   7.9250        S           1     True
# 3       1  female  35.0      1      0  53.1000        S           2    False
# 4       3    male  35.0      0      0   8.0500        S           1     True
#
#    Has_cabin
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False

# %%
# Label encoding of categorical features
# from sklearn.preprocessing import LabelEncoder

# encoder=LabelEncoder()


# df['Sex']=encoder.fit_transform(df['Sex'])

# df['Embarked']=encoder.fit_transform(df['Embarked'])
# df['isAlone']=encoder.fit_transform(df['isAlone'])
# df['Has_cabin']=encoder.fit_transform(df['Has_cabin'])

# print(X_train.dtypes)




from sklearn.preprocessing import LabelEncoder

# Create LabelEncoder instance
le = LabelEncoder()

# Convert 'Sex' column (Male → 1, Female → 0)
X_train['Sex'] = le.fit_transform(X_train['Sex'])
X_test['Sex'] = le.transform(X_test['Sex'])

# Convert 'Embarked' column if needed
X_train['Embarked'] = le.fit_transform(X_train['Embarked'])
X_test['Embarked'] = le.transform(X_test['Embarked'])

print(X_train.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 24
#      21 le = LabelEncoder()
#      23 # Convert 'Sex' column (Male → 1, Female → 0)
# ---> 24 X_train['Sex'] = le.fit_transform(X_train['Sex'])
#      25 X_test['Sex'] = le.transform(X_test['Sex'])
#      27 # Convert 'Embarked' column if needed
#
# NameError: name 'X_train' is not defined

# %%
# concat df_categorical with original df

# %%
#Do a pairplot of all features
sns.pairplot(df)
plt.show()

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=10)

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library

from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X_train,y_train)


# print(X_train.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 7
#       5 from sklearn.tree import DecisionTreeClassifier
#       6 model=DecisionTreeClassifier()
# ----> 7 model.fit(X_train,y_train)
#      10 # print(X_train.dtypes)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\tree\_classes.py:1024, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
# ...

# %%
#Print the tree

# Importing required packages for visualization

from sklearn.tree import plot_tree

# Visualizing the tree
plt.figure(figsize=(80,50))
plot_tree(model,  filled=True)
plt.show()

# %%
# plotting tree with max_depth=3

from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier(max_depth=3)
model2.fit(x_train,y_train)

from sklearn import tree

# Visualizing the tree
plt.figure(figsize=(80,50))
plot_tree(model2,  filled=True, class_names=['Not Survived', 'Survived'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 5
#       3 from sklearn.tree import DecisionTreeClassifier
#       4 model2=DecisionTreeClassifier(max_depth=3)
# ----> 5 model2.fit(x_train,y_train)
#       7 from sklearn import tree
#       9 # Visualizing the tree
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report

# %%
# Printing confusion matrix and accuracy

# %%
# sns.countplot(x="Survived",data=df,color="blue")
