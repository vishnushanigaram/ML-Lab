# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

import pandas as pd
df = pd.read_csv('tvmarketing.csv')
print(df.head())
print(df.dtypes)

print(df.describe())
X=df.drop('Sales',axis=1)
y=df['Sales']

plt.scatter(df['TV'], df['Sales'])
plt.show()

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)

print("Linear Regression with using any libray")

x_mean=np.mean(X_train)
y_mean=np.mean(y_train)

num=sum((X_train['TV']-x_mean)*(y_train-y_mean))
den=sum((X_train['TV']-x_mean)**2)

t1=num/den #Sloppe
t0=y_mean-(t1*x_mean) #Inttercept

print(t1,t0)

y_predm=t0+(t1*X_test)
print(y_predm)


from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

print("Intercept", model.intercept_)
print("Coef",model.coef_)




plt.scatter(X_train, y_train, )
plt.plot(X_train,model.predict(X_train),color='red',label='Train')
plt.show()


plt.scatter(X_test, y_test, )
plt.plot(X_test,y_pred,color='red',label='Test')
plt.show()



from sklearn.metrics import mean_squared_error,accuracy_score,r2_score,confusion_matrix
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))


print("R suqared error")

numm=sum((y_test-y_pred)**2)
denn=sum((y_test-y_mean)**2)
r2=1-(numm/denn)
print(r2)

print("Adjusted R suqared error")
n=len(y_test)
p=X_test.shape[1]
adj_r2=1-((1-r2)*(n-1)/(n-p-1))
print(adj_r2)

# %%
plt.scatter(X_train, y_train, )
plt.plot(X_train,model.predict(X_train),color='red',label='Train')
plt.show()

# %%
plt.scatter(X_test, y_test, )
plt.plot(X_test,y_pred,color='red',label='Train')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,accuracy_score,r2_score,confusion_matrix
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))


print("R suqared error")

numm=sum((y_test-y_pred)**2)
denn=sum((y_test-y_mean)**2)
r2=1-(numm/denn)
print(r2)

print("Adjusted R suqared error")
n=len(y_test)
p=X_test.shape[1]
adj_r2=1-((1-r2)*(n-1)/(n-p-1))
print(adj_r2)
# Out:
# 9.6705964754053
# 0.6047520456673384
# R suqared error
# 0.6073047648539929
# Adjusted R suqared error
# 0.6005341573514755

# %%
print(df.dtypes)
# Out:
# TV       float64
# Sales    float64
# dtype: object

# %%
print(df.shape)
# Out:
# (200, 2)

# %%
print(df.describe())
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(df['TV'], df['Sales'])
plt.xlabel("TV Marketing Budget")
plt.ylabel("Sales")
plt.title("TV Budget vs Sales")
plt.show()

# %%
X = df[['TV']]  # Feature (Independent Variable)
y = df['Sales']  # Target (Dependent Variable)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (140, 1) (60, 1)
# (140,) (60,)

# %%
import numpy as np

X_mean = np.mean(X_train)
y_mean = np.mean(y_train)

num = sum((X_train['TV'] - X_mean) * (y_train - y_mean))
den = sum((X_train['TV'] - X_mean) ** 2)

m = num / den  # slope 
c = y_mean - (m * X_mean)  # intercept

print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.047313877805369865, Intercept: 7.076184032676628

# %%
y_pred_manual = m * X_test + c
print(y_pred_manual)
# Out:
#             TV
# 3    14.244237
# 37   10.610531
# 49   10.241482
# 111  18.511948
# 41   15.450740
# 85   16.217225
# 7    12.763312
# 191  10.648382
# 132   7.473621
# 167  16.860694
# 77   12.777506
# 146  18.436246
# 133  17.475774
# 6     9.796732
# 108   7.695996
# 76    8.377316
# 26   13.837337
# 159  13.307422
# 155   7.270171
# 112  15.389232
# 95   14.802540
# 170   9.441878
# 193  14.968139
# 189   7.960954
# 74   17.172966
# 144  11.627779
# 148   8.874111
# 119   7.994073
# 143  12.025216
# 160  15.237828
# 47   18.426783
# 105  13.600768
# 198  20.494400
# 169  20.527519
# 117  10.690964
# 107  11.353359
# 196  11.533151
# 0    17.963107
# 141  16.240882
# 150  20.357190
# 140  10.549023
# 23   17.877942
# 103  15.966462
# 48   17.825897
# 92   17.376415
# 35   20.830328
# 172   8.003536
# 45   15.360844
# 27   18.436246
# 33   19.642750
# 190   8.945082
# 18   10.350304
# 86   10.686233
# 145  13.714321
# 43   16.865425
# 39   17.863748
# 93   18.947236
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train, y_train)
print(model.intercept_)
print(model.coef_)
# Out:
# 7.07618403267663
# [0.04731388]

# %%
new_predictions = model.predict(X_test)
print(new_predictions)
# Out:
# [14.24423652 10.6105307  10.24148246 18.5119483  15.4507404  16.21722522
#  12.76331214 10.64838181  7.47362061 16.86069396 12.77750631 18.43624609
#  17.47577437  9.79673201  7.69599583  8.37731567 13.83733717 13.30742174
#   7.27017093 15.38923236 14.80254028  9.44187792 14.96813885  7.96095355
#  17.17296556 11.62777908  8.87411139  7.99407326 12.02521565 15.23782795
#  18.42678332 13.60076778 20.49439978 20.52751949 10.6909643  11.35335859
#  11.53315132 17.96310732 16.24088216 20.35718953 10.54902266 17.87794234
#  15.96646167 17.82589707 17.37641523 20.83032831  8.00353604 15.36084404
#  18.43624609 19.64274998  8.94508221 10.35030438 10.68623291 13.71432109
#  16.86542535 17.86374817 18.94723597 10.63891903 20.68365529  7.92310245]

# %%
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, model.predict(X_train), color='red')
plt.xlabel("TV Marketing Budget")
plt.ylabel("Sales")
plt.title("Train Data with Regression Line")
plt.show()

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, model.predict(X_test), color='red')
plt.xlabel("TV Marketing Budget")
plt.ylabel("Sales")
plt.title("Train Data with Regression Line")
plt.show()

# %%
plt.scatter(X_test, y_test, color='green')
plt.plot(X_test, new_predictions, color='red')
plt.xlabel("TV Marketing Budget")
plt.ylabel("Sales")
plt.title("Test Data with Regression Line")
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score,accuracy_score,f1_score,precision_score,recall_score

mse = mean_squared_error(y_test, new_predictions)
r2 = r2_score(y_test, new_predictions)
accuracy_scores = accuracy_score(y_test, new_predictions)
f1_scores = f1_score(y_test, new_predictions)
precision_scores = precision_score(y_test, new_predictions)
recall_scores = recall_score(y_test, new_predictions)

print(f"accuracy score : {accuracy_scores}" )
print(f"recall_score : {recall_scores}")
print(f"predictions_score : {prediction_scores}")


print(f"Mean Squared Error: {mse}")

print(f"R-squared: {r2}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 5
#       3 mse = mean_squared_error(y_test, new_predictions)
#       4 r2 = r2_score(y_test, new_predictions)
# ----> 5 accuracy_scores = accuracy_score(y_test, new_predictions)
#       6 f1_scores = f1_score(y_test, new_predictions)
#       7 precision_scores = precision_score(y_test, new_predictions)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
# ...

# %%
y_test_mean=np.mean(y_test)
num=np.sum(y_test-new_predictions)**2
den=np.sum(y_test-y_test_mean)**2
com=num/den
print(1-com)
# Out:
# -5.507397611612908e+29

# %%
y_test_mean=np.mean(y_test)
num=np.sum(new_predictions-y_test_mean)**2
den=np.sum(y_test-y_test_mean)**2
com=num/den
print(com)
# Out:
# 5.507397611612941e+29

# %%
r2=np.sum((new_predictions - y_test_mean)**2)/np.sum((y_test-y_test_mean)**2)
print(1-r2)
# Out:
# 0.24043486746856257
